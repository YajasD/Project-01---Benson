# %% [markdown]
# # PROBLEM STATEMENT:
#
# WTWY needs to optimize their street teams so that they can get the most email signups for their annual OMGYN Gala. Ideally, the email signups will convert at a high rate to gala attendees, and among attendees, many will make contributions to WTWY.
#
#     -Find most number of people
#
#     -Find people that have a high chance of attending GALA
#
#         -Are they interested in Tech?
#         -Are they interested in Women in Tech?
#         -Do they have disposable income?
#         -Are they Charitable?
#
# MTA data obtained from the NYC Data Portal provides rich information about the travel patterns of New Yorkers -- using this information, can we create a street team deployment plan that will optimize WTWY’s resources toward achieving their goals?
#
#     -http://web.mta.info/developers/turnstile.html

# %%
import sys
print("Python version:", sys.version)
# Out:
# Python version: 3.6.5 (default, Mar 30 2018, 06:42:10)
# [GCC 4.2.1 Compatible Apple LLVM 9.0.0 (clang-900.0.39.2)]

# %%
import urllib.request

print('Beginning file download with urllib2...')

url = 'http://web.mta.info/developers/data/nyct/turnstile/turnstile_180407.txt'  
urllib.request.urlretrieve(url, '/Users/yajasdwivedi/mta_data.txt')
# Out:
# Beginning file download with urllib2...
# ('/Users/yajasdwivedi/mta_data.txt', <http.client.HTTPMessage at 0x1173a21d0>)

# %%
#import csv
import pandas as pd
mta_df = pd.read_csv(url)

#mta_df = pd.DataFrame(mta_df)
#mta_df = pd.DataFrame(mta_df, names = column)
mta_df
# Out:
#           C/A  UNIT       SCP        STATION LINENAME DIVISION        DATE  \
# 0        A002  R051  02-00-00          59 ST  NQR456W      BMT  03/31/2018
# 1        A002  R051  02-00-00          59 ST  NQR456W      BMT  03/31/2018
# 2        A002  R051  02-00-00          59 ST  NQR456W      BMT  03/31/2018
# 3        A002  R051  02-00-00          59 ST  NQR456W      BMT  03/31/2018
# 4        A002  R051  02-00-00          59 ST  NQR456W      BMT  03/31/2018
# 5        A002  R051  02-00-00          59 ST  NQR456W      BMT  03/31/2018
# 6        A002  R051  02-00-00          59 ST  NQR456W      BMT  04/01/2018
# 7        A002  R051  02-00-00          59 ST  NQR456W      BMT  04/01/2018
# 8        A002  R051  02-00-00          59 ST  NQR456W      BMT  04/01/2018
# 9        A002  R051  02-00-00          59 ST  NQR456W      BMT  04/01/2018
# 10       A002  R051  02-00-00          59 ST  NQR456W      BMT  04/01/2018
# ...

# %%
mta_df = mta_df.rename(columns=lambda x: x.strip())

# %%
mta_df.DATE.value_counts()
# Out:
# 04/05/2018    28262
# 04/03/2018    28189
# 04/04/2018    28154
# 03/31/2018    28129
# 04/06/2018    28121
# 04/01/2018    28084
# 04/02/2018    28049
# Name: DATE, dtype: int64

# %%
mta_df_subset1 = mta_df[['STATION','DATE','TIME','ENTRIES','EXITS']]
mta_df_subset1
# Out:
#               STATION        DATE      TIME  ENTRIES    EXITS
# 0               59 ST  03/31/2018  00:00:00  6566463  2224050
# 1               59 ST  03/31/2018  04:00:00  6566470  2224053
# 2               59 ST  03/31/2018  08:00:00  6566470  2224053
# 3               59 ST  03/31/2018  12:00:00  6566470  2224055
# 4               59 ST  03/31/2018  16:00:00  6566470  2224055
# 5               59 ST  03/31/2018  20:00:00  6566470  2224055
# 6               59 ST  04/01/2018  00:00:00  6566470  2224055
# 7               59 ST  04/01/2018  04:00:00  6566470  2224055
# 8               59 ST  04/01/2018  08:00:00  6566470  2224055
# 9               59 ST  04/01/2018  12:00:00  6566470  2224055
# 10              59 ST  04/01/2018  16:00:00  6566470  2224055
# 11              59 ST  04/01/2018  20:00:00  6566470  2224055
# 12              59 ST  04/02/2018  00:00:00  6566470  2224055
# 13              59 ST  04/02/2018  04:00:00  6566470  2224055
# ...

# %% [markdown]
# #newdf = df[(df['column_one']>2004) & (df['column_two']==9)]
# mta_df[['EXITS']]
